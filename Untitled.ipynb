# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest, chi2

# %%
dataset = pd.read_csv('bcsc_risk_factors_summarized1_092020.csv')
dataset.head()
# Out:
#    year  age_group_5_years  race_eth  first_degree_hx  age_menarche  \
# 0  2013                  7         1                0             9
# 1  2013                  7         1                0             9
# 2  2013                  7         1                0             9
# 3  2013                  7         1                0             9
# 4  2013                  7         1                0             9
#
#    age_first_birth  BIRADS_breast_density  current_hrt  menopaus  bmi_group  \
# 0                3                      1            1         2          3
# 1                3                      1            1         2          3
# 2                3                      1            1         2          4
# 3                3                      1            1         2          4
# 4                3                      1            1         2          4
#
#    biophx  breast_cancer_history  count
# 0       0                      0      7
# 1       1                      0      3
# 2       0                      0      6
# 3       1                      0      1
# 4       1                      1      1
